# %%
# program to add an item to a dictionary
D = {1: "Pranit", 2: "Sradha"}
D[3] = "Ishan"
print("mew dictionary:", D)
# Out:
# mew dictionary: {1: 'Pranit', 2: 'Sradha', 3: 'Ishan'}

# %%
# program to concatenate multiple dictionaries
D1 = {1:"Pranit"}
D2 = {2:"Shubh"}
D3 = {3:"Ishan"}
D = {}
D.update(D1)
D.update(D2)
D.update(D3)
print("new dictionary:", D)
# Out:
# new dictionary: {1: 'Pranit', 2: 'Shubh', 3: 'Ishan'}
